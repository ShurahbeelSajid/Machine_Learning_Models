# %% [markdown]
# Pakistan Weather Prediction
#
# Dataset [ link](https://www.ncdc.noaa.gov/cdo-web/search)

# %%
import pandas as pd
df = pd.read_csv("/content/3700340.csv", index_col="DATE")

# %%
df.head()
# Out:
#                 STATION        NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 2024-01-01  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-02  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-03  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-05  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-06  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
#
#            PRCP_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX  \
# DATE
# 2024-01-01             NaN   NaN             NaN    44            H,,S   NaN
# 2024-01-02             NaN   NaN             NaN    46            H,,S   NaN
# 2024-01-03             NaN   NaN             NaN    44            H,,S   NaN
# 2024-01-05             NaN   NaN             NaN    44            H,,S   NaN
# 2024-01-06             NaN   NaN             NaN    45            H,,S   NaN
#
# ...

# %%
df.tail()
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-21  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-22  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-23  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
#
#            PRCP_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES   TMAX  \
# DATE
# 2024-05-19             ,,S   NaN             NaN    90            H,,S  103.0
# 2024-05-20             ,,S   NaN             NaN    90            H,,S  102.0
# 2024-05-21             ,,S   NaN             NaN    92            H,,S  104.0
# 2024-05-22             ,,S   NaN             NaN    93            H,,S  106.0
# 2024-05-23             ,,S   NaN             NaN    99            H,,S  108.0
#
# ...

# %%
df.shape
# Out:
# (3390, 15)

# %%
df.describe()
# Out:
#           LATITUDE    LONGITUDE    ELEVATION         PRCP      SNWD  \
# count  3390.000000  3390.000000  3390.000000  2760.000000  7.000000
# mean     29.556055    68.810546   612.530413     0.057380  0.742857
# std       3.115495     3.555944   630.929060     0.254039  0.427618
# min      24.907000    61.805000     3.700000     0.000000  0.400000
# 25%      26.955000    66.633000    58.000000     0.000000  0.400000
# 50%      29.033000    69.467000   256.000000     0.000000  0.400000
# 75%      31.909000    71.419000  1098.000000     0.000000  1.200000
# max      35.567000    74.533000  2017.000000     5.390000  1.200000
#
#               TAVG         TMAX         TMIN
# count  3390.000000  2895.000000  2452.000000
# mean     66.858112    80.860449    57.315661
# std      15.069924    15.914309    13.841907
# min      24.000000    29.000000    18.000000
# 25%      56.000000    70.000000    47.000000
# 50%      66.000000    81.000000    57.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3390 entries, 2024-01-01 to 2024-05-23
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATION          3390 non-null   object
#  1   NAME             3390 non-null   object
#  2   LATITUDE         3390 non-null   float64
#  3   LONGITUDE        3390 non-null   float64
#  4   ELEVATION        3390 non-null   float64
#  5   PRCP             2760 non-null   float64
#  6   PRCP_ATTRIBUTES  2760 non-null   object
#  7   SNWD             7 non-null      float64
#  8   SNWD_ATTRIBUTES  7 non-null      object
#  9   TAVG             3390 non-null   int64
#  10  TAVG_ATTRIBUTES  3390 non-null   object
#  11  TMAX             2895 non-null   float64
#  12  TMAX_ATTRIBUTES  2895 non-null   object
#  13  TMIN             2452 non-null   float64
#  14  TMIN_ATTRIBUTES  2452 non-null   object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 423.8+ KB

# %%
null = df.apply(pd.isnull).sum()   #Display null value
null
# Out:
# STATION               0
# NAME                  0
# LATITUDE              0
# LONGITUDE             0
# ELEVATION             0
# PRCP                630
# PRCP_ATTRIBUTES     630
# SNWD               3383
# SNWD_ATTRIBUTES    3383
# TAVG                  0
# TAVG_ATTRIBUTES       0
# TMAX                495
# TMAX_ATTRIBUTES     495
# TMIN                938
# TMIN_ATTRIBUTES     938
# dtype: int64

# %%
null = df.apply(pd.isnull).sum()/df.shape[0] * 100  #Dsiplay %age of null values
null
# Out:
# STATION             0.000000
# NAME                0.000000
# LATITUDE            0.000000
# LONGITUDE           0.000000
# ELEVATION           0.000000
# PRCP               18.584071
# PRCP_ATTRIBUTES    18.584071
# SNWD               99.793510
# SNWD_ATTRIBUTES    99.793510
# TAVG                0.000000
# TAVG_ATTRIBUTES     0.000000
# TMAX               14.601770
# TMAX_ATTRIBUTES    14.601770
# TMIN               27.669617
# TMIN_ATTRIBUTES    27.669617
# dtype: float64

# %% [markdown]
# Machine Learning models doesnot appreciate null values.

# %%
df = df.drop(columns = "PRCP_ATTRIBUTES") #droping unnecessary columns
df = df.drop(columns = "TMAX_ATTRIBUTES")
df = df.drop(columns = "TAVG_ATTRIBUTES")
df = df.drop(columns = "TMIN_ATTRIBUTES")
df = df.drop(columns = "SNWD_ATTRIBUTES")
df = df.drop(columns = "SNWD")

# %%
def fahrenheit_to_celsius(f):
    return (f - 32) * 5.0/9.0

# %%
 #temperatue is in Fahrenheit, we need to convert it into celsius
df['TAVG'] = df['TAVG'].apply(fahrenheit_to_celsius)
df['TMAX'] = df['TMAX'].apply(fahrenheit_to_celsius)
df['TMIN'] = df['TMIN'].apply(fahrenheit_to_celsius)

# %%
df.head(60)
# Out:
#                 STATION        NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 2024-01-01  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-02  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-03  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-05  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-06  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-08  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-09  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-10  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-11  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-12  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-13  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# 2024-01-14  PKM00041660  QUETTA, PK    30.251     66.938     1600.2   NaN
# ...

# %%
# df = df.ffill()  #replacing the missing values from  columns with last non  missing values

# %%
df.apply(pd.isnull).sum() #check for  missing values now
# Out:
# STATION        0
# NAME           0
# LATITUDE       0
# LONGITUDE      0
# ELEVATION      0
# PRCP         630
# TAVG           0
# TMAX         495
# TMIN         938
# dtype: int64

# %%
df['PRCP'].mean()
# Out:
# 0.057380434782608694

# %%
df['PRCP'].fillna(0.047, inplace=True)

# %%
df['TMAX'].mean()
# Out:
# 27.144693916714644

# %%
df['TMAX'].fillna(27.14, inplace=True)

# %%
df['TMIN'].mean()
# Out:
# 14.064255936197208

# %%
df['TMIN'].fillna(14.06, inplace=True)

# %%
df['TAVG'].mean()
# Out:
# 19.3656178302196

# %%
df['TAVG'].fillna(19.36, inplace=True)

# %%
df.apply(pd.isnull).sum() #check for  missing values now
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# PRCP         0
# TAVG         0
# TMAX         0
# TMIN         0
# dtype: int64

# %%
df.copy()
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 2024-01-01  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-02  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-03  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-05  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-06  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# ...                 ...             ...       ...        ...        ...
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-21  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-22  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-23  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
#
#              PRCP       TAVG       TMAX       TMIN
# DATE
# ...

# %%
df.dtypes
# Out:
# STATION       object
# NAME          object
# LATITUDE     float64
# LONGITUDE    float64
# ELEVATION    float64
# PRCP         float64
# TAVG         float64
# TMAX         float64
# TMIN         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3390 entries, 2024-01-01 to 2024-05-23
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    3390 non-null   object
#  1   NAME       3390 non-null   object
#  2   LATITUDE   3390 non-null   float64
#  3   LONGITUDE  3390 non-null   float64
#  4   ELEVATION  3390 non-null   float64
#  5   PRCP       3390 non-null   float64
#  6   TAVG       3390 non-null   float64
#  7   TMAX       3390 non-null   float64
#  8   TMIN       3390 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 264.8+ KB

# %%
df.index
# Out:
# Index(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-05', '2024-01-06',
#        '2024-01-08', '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#        ...
#        '2024-05-14', '2024-05-15', '2024-05-16', '2024-05-17', '2024-05-18',
#        '2024-05-19', '2024-05-20', '2024-05-21', '2024-05-22', '2024-05-23'],
#       dtype='object', name='DATE', length=3390)

# %%
df.index = pd.to_datetime(df.index) #converting index(date) to date time via pandas for ease

# %%
df.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-05',
#                '2024-01-06', '2024-01-08', '2024-01-09', '2024-01-10',
#                '2024-01-11', '2024-01-12',
#                ...
#                '2024-05-14', '2024-05-15', '2024-05-16', '2024-05-17',
#                '2024-05-18', '2024-05-19', '2024-05-20', '2024-05-21',
#                '2024-05-22', '2024-05-23'],
#               dtype='datetime64[ns]', name='DATE', length=3390, freq=None)

# %%
df.index.month.value_counts().sort_index()
# Out:
# DATE
# 1    762
# 2    723
# 3    651
# 4    704
# 5    550
# Name: count, dtype: int64

# %%
df["TAVG"].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='DATE'>

# %%
df.tail(5)
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-21  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-22  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
# 2024-05-23  PK000041712  DAL BANDIN, PK    28.883       64.4      850.0   0.0
#
#                  TAVG       TMAX       TMIN
# DATE
# 2024-05-19  32.222222  39.444444  23.888889
# 2024-05-20  32.222222  38.888889  25.000000
# 2024-05-21  33.333333  40.000000  24.444444
# 2024-05-22  33.888889  41.111111  26.666667
# 2024-05-23  37.222222  42.222222  27.777778

# %%
df['NAME'].unique()
# Out:
# array(['QUETTA, PK', 'JINNAH INTERNATIONAL, PK', 'BAR KHAN, PK',
#        'SIALKOT, PK', 'HYDERABAD AIRPORT, PK', 'D I KHAN, PK',
#        'KHUZDAR, PK', 'CHHOR, PK', 'SHAHBAZ AB, PK', 'PASNI, PK',
#        'KHANPUR, PK', 'PANJGUR, PK', 'CHAKLALA, PK',
#        'PESHAWAR INTERNATIONAL, PK', 'PARACHINAR, PK', 'JHELUM, PK',
#        'MULTAN INTERNATIONAL, PK', 'KALAT, PK', 'NOKKUNDI, PK',
#        'LAHORE CITY, PK', 'JIWANI, PK', 'ZHOB, PK', 'DROSH, PK',
#        'NAWABSHAH, PK', 'DAL BANDIN, PK'], dtype=object)

# %%
area_name = df[df['NAME'] == 'MULTAN INTERNATIONAL, PK']
area_name
# Out:
#                 STATION                      NAME  LATITUDE  LONGITUDE  \
# DATE
# 2024-01-01  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-01-02  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-01-03  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-01-04  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-01-05  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# ...                 ...                       ...       ...        ...
# 2024-05-19  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-05-20  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-05-21  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-05-22  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
# 2024-05-23  PKM00041675  MULTAN INTERNATIONAL, PK    30.203     71.419
#
#             ELEVATION   PRCP       TAVG       TMAX       TMIN
# DATE
# ...

# %%
area_name[['TMAX','TAVG','TMIN']].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='DATE'>

# %%
df['target'] = df.shift(-1)['TMAX']
df
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 2024-01-01  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-02  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-03  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-05  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-06  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# ...                 ...             ...       ...        ...        ...
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-21  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-22  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-23  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
#
#              PRCP       TAVG       TMAX       TMIN     target
# DATE
# ...

# %%
df = df.ffill()
df
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 2024-01-01  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-02  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-03  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-05  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# 2024-01-06  PKM00041660      QUETTA, PK    30.251     66.938     1600.2
# ...                 ...             ...       ...        ...        ...
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-21  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-22  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
# 2024-05-23  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0
#
#              PRCP       TAVG       TMAX       TMIN     target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = df.columns[~df.columns.isin(["target", "NAME", "STATION"])]

# %%
predictors
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'ELEVATION', 'PRCP', 'TAVG', 'TMAX', 'TMIN'], dtype='object')

# %%
def backtest(df, model, predictors, start = 144, step = 5):
  all_predictions = []

  for i in range(start, df.shape[0], step):
    train = df.iloc[:i,:]
    test = df.iloc[i:(i+step),:]

    model.fit(train[predictors], train["target"])

    preds = model.predict(test[predictors])

    preds = pd.Series(preds, index = test.index)
    combined = pd.concat([test['target'], preds], axis = 1)

    combined.columns = ['actual','prediction']

    combined['diff'] = (combined['prediction'] - combined['actual']).abs()

    all_predictions.append(combined)
  return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions.tail()
# Out:
#                actual  prediction      diff
# DATE
# 2024-05-19  38.888889   37.859057  1.029831
# 2024-05-20  40.000000   37.615475  2.384525
# 2024-05-21  41.111111   38.488655  2.622456
# 2024-05-22  42.222222   39.457695  2.764528
# 2024-05-23  42.222222   40.999020  1.223202

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions['actual'], predictions['prediction'])
# Out:
# 2.4554789205779133

# %%
predictions['diff'].mean()
# Out:
# 2.4554789205779133

# %%
df.loc['2024-04-01':'2024-05-20']
# Out:
#                 STATION            NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP  \
# DATE
# 2024-04-03  PKM00041660      QUETTA, PK    30.251     66.938     1600.2   0.0
# 2024-04-04  PKM00041660      QUETTA, PK    30.251     66.938     1600.2   0.0
# 2024-04-05  PKM00041660      QUETTA, PK    30.251     66.938     1600.2   0.0
# 2024-04-06  PKM00041660      QUETTA, PK    30.251     66.938     1600.2   0.0
# 2024-04-07  PKM00041660      QUETTA, PK    30.251     66.938     1600.2   0.0
# ...                 ...             ...       ...        ...        ...   ...
# 2024-05-16  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0   0.0
# 2024-05-17  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0   0.0
# 2024-05-18  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0   0.0
# 2024-05-19  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0   0.0
# 2024-05-20  PK000041712  DAL BANDIN, PK    28.883     64.400      850.0   0.0
#
# ...

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: xlabel='diff'>
